# %%
# 验证 delta_T
from utils.train_func import train_func
from datetime import datetime
from tqdm import tqdm
import numpy as np
import json
import os
import matplotlib.pyplot as plt
from utils.tools import make_dir


modelList = ['SeEANet', 'SAT', 'MyoNet']
data_dict = {}
# delta_Tlist = [1, 10, 15, 20, 25, 30, 40, 50, 60]
# delta_Tlist = [1, 5, 10, 15, 20, 25, 30, 35, 40, 50, 60, 70, 80, 90 ,100, 120, 140, 160, 180, 200, 230, 260, 300]
# delta_Tlist = [260, 300]
# # people_List = ['S01', 'S02', "S03"]
# people_List = ['S01']

delta_Tlist = [i for i in range(11, 21)]
people_List = ['S01']

rmseL = []
maeL = []
r2L = []
formatted_time = datetime.now().strftime("%m-%d-%H:%M:%S")
make_dir(os.path.join('/home/admin123/SATData/Run', formatted_time))
for delta_T in tqdm(delta_Tlist, desc="Processing", position=0):
    rmse, mae, r2 = train_func(modelName='SeEANet', epochs=1500, train_num=20, delta_T=delta_T,
                               formatted_time = formatted_time, peopleList=people_List, batch_size=256)
    rmse = np.array(rmse)
    rmse_m = np.mean(rmse,axis=0)
    rmse_s = np.std(rmse, axis=0)
    rmse_d = np.max(rmse, axis=0)-np.min(rmse, axis=0)
    rmseL.append(rmse_m)

    mae = np.array(mae)
    mae_m = np.mean(mae,axis=0)
    mae_s = np.std(mae, axis=0)
    mae_d = np.max(mae, axis=0)-np.min(mae, axis=0)
    maeL.append(mae_m)

    r2 = np.array(r2)
    r2_m = np.mean(r2,axis=0)
    r2_s = np.std(r2, axis=0)
    r2_d = np.max(r2, axis=0)-np.min(r2, axis=0)
    r2L.append(r2_m)

    data_dict[f"rmse_{delta_T}"] = [list(rmse_m), list(rmse_s), list(rmse_d)]
    data_dict[f"mae_{delta_T}"] = [list(mae_m), list(mae_s), list(mae_d)]
    data_dict[f"r2_{delta_T}"] = [list(r2_m), list(r2_s), list(r2_d)]

# 指定 JSON 文件路径
file_path = os.path.join('/home/admin123/SATData/Run/', formatted_time, "data.json")

with open(file_path, "w", encoding="utf-8") as file:
    json.dump(data_dict, file, ensure_ascii=False, indent=4)

print(f"字典已成功保存到 {file_path}")


rmseL = np.array(rmseL)
maeL = np.array(maeL)
r2L = np.array(r2L)


plt.figure()
png_path = os.path.join('/home/admin123/SATData/Run', formatted_time, "RMSE.png")
plt.plot(delta_Tlist, rmseL[:,0], marker='o', linestyle='-', label='elv_angle')  # 线条和点
plt.plot(delta_Tlist, rmseL[:,1], marker='o', linestyle='-', label='shoulder_elv')  # 线条和点
plt.plot(delta_Tlist, rmseL[:,2], marker='o', linestyle='-', label='elbow_flexion')  # 线条和点
plt.xlabel("dleta_T")
plt.ylabel("value")
plt.grid()
plt.legend()
plt.title("RMSE")
plt.savefig(png_path, dpi=300, bbox_inches='tight')
# plt.scatter(x, y, color='r', label='Points')  # 单独绘制点 


plt.figure()
png_path = os.path.join('/home/admin123/SATData/Run', formatted_time, "MAE.png")
plt.plot(delta_Tlist, maeL[:,0], marker='o', linestyle='-', label='elv_angle')  # 线条和点
plt.plot(delta_Tlist, maeL[:,1], marker='o', linestyle='-', label='shoulder_elv')  # 线条和点
plt.plot(delta_Tlist, maeL[:,2], marker='o', linestyle='-', label='elbow_flexion')  # 线条和点
plt.xlabel("dleta_T")
plt.ylabel("value")
plt.title("MAE")
plt.grid()
plt.legend()
plt.savefig(png_path, dpi=300, bbox_inches='tight')


plt.figure()
png_path = os.path.join('/home/admin123/SATData/Run', formatted_time, "R2.png")
plt.plot(delta_Tlist, r2L[:,0], marker='o', linestyle='-', label='elv_angle')  # 线条和点
plt.plot(delta_Tlist, r2L[:,1], marker='o', linestyle='-', label='shoulder_elv')  # 线条和点
plt.plot(delta_Tlist, r2L[:,2], marker='o', linestyle='-', label='elbow_flexion')  # 线条和点
plt.xlabel("dleta_T")
plt.ylabel("value")
plt.title("R2")
plt.grid()
plt.legend()
plt.savefig(png_path, dpi=300, bbox_inches='tight')
# Out:
# Processing:   0%|          | 0/2 [00:00<?, ?it/s]
# 训练参数：网络：SeEANet, 簇:6, 间隔时间: 260, 数据融合算法: PCA
# semg 数据形状为： torch.Size([24245, 6, 256])
# angle 数据形状为： torch.Size([24245, 3])
# 开始第1次训练！！！
# Epoch 100, train_idnex=1, Train Loss: 491.68258, Test Loss: 474.36231
# Epoch 200, train_idnex=1, Train Loss: 21.26775, Test Loss: 27.77301
# Epoch 300, train_idnex=1, Train Loss: 9.31665, Test Loss: 10.63434
# Epoch 400, train_idnex=1, Train Loss: 3.84210, Test Loss: 6.13686
# Epoch 500, train_idnex=1, Train Loss: 2.22111, Test Loss: 4.02752
# Epoch 600, train_idnex=1, Train Loss: 1.52874, Test Loss: 3.30245
# Epoch 700, train_idnex=1, Train Loss: 1.29474, Test Loss: 2.93579
# Epoch 800, train_idnex=1, Train Loss: 1.16928, Test Loss: 2.77904
# Epoch 900, train_idnex=1, Train Loss: 1.10835, Test Loss: 2.69523
# Epoch 1000, train_idnex=1, Train Loss: 1.07811, Test Loss: 2.64730
# Epoch 1100, train_idnex=1, Train Loss: 1.06186, Test Loss: 2.63387
# Epoch 1200, train_idnex=1, Train Loss: 1.05383, Test Loss: 2.62492
# Epoch 1300, train_idnex=1, Train Loss: 1.04918, Test Loss: 2.61756
# Epoch 1400, train_idnex=1, Train Loss: 1.04682, Test Loss: 2.61949
# Epoch 1500, train_idnex=1, Train Loss: 1.04473, Test Loss: 2.61937
# loss csv 文件已保存到: /home/admin123/SATData/Run/SeEANet/04-16-19:42:36/MJ_PCA_260_256/output_1.csv
# loss png 文件已保存到: /home/admin123/SATData/Run/SeEANet/04-16-19:42:36/MJ_PCA_260_256/loss_1.png
# 开始第2次训练！！！
# Epoch 100, train_idnex=2, Train Loss: 26446.32056, Test Loss: 26001.78467
# Epoch 200, train_idnex=2, Train Loss: 61.37542, Test Loss: 84.21516
# Epoch 300, train_idnex=2, Train Loss: 15.48893, Test Loss: 22.81728
# Epoch 400, train_idnex=2, Train Loss: 6.01190, Test Loss: 10.06226
# Epoch 500, train_idnex=2, Train Loss: 3.73951, Test Loss: 7.55720
# Epoch 600, train_idnex=2, Train Loss: 2.70901, Test Loss: 6.00424
# Epoch 700, train_idnex=2, Train Loss: 2.22218, Test Loss: 5.41492
# Epoch 800, train_idnex=2, Train Loss: 2.01820, Test Loss: 5.07219
# Epoch 900, train_idnex=2, Train Loss: 1.89890, Test Loss: 4.96579
# Epoch 1000, train_idnex=2, Train Loss: 1.84617, Test Loss: 4.88349
# Epoch 1100, train_idnex=2, Train Loss: 1.81758, Test Loss: 4.85264
# Epoch 1200, train_idnex=2, Train Loss: 1.80331, Test Loss: 4.83696
# Epoch 1300, train_idnex=2, Train Loss: 1.79473, Test Loss: 4.82521
# Epoch 1400, train_idnex=2, Train Loss: 1.79082, Test Loss: 4.82001
# Epoch 1500, train_idnex=2, Train Loss: 1.78813, Test Loss: 4.82047
# loss csv 文件已保存到: /home/admin123/SATData/Run/SeEANet/04-16-19:42:36/MJ_PCA_260_256/output_2.csv
# loss png 文件已保存到: /home/admin123/SATData/Run/SeEANet/04-16-19:42:36/MJ_PCA_260_256/loss_2.png
# 开始第3次训练！！！
# Epoch 100, train_idnex=3, Train Loss: 432.69577, Test Loss: 379.94710
# Epoch 200, train_idnex=3, Train Loss: 18.57022, Test Loss: 26.78964
# Epoch 300, train_idnex=3, Train Loss: 6.32284, Test Loss: 9.07901
# Epoch 400, train_idnex=3, Train Loss: 2.44993, Test Loss: 4.54073
# Epoch 500, train_idnex=3, Train Loss: 1.41999, Test Loss: 3.21069
# Epoch 600, train_idnex=3, Train Loss: 1.03842, Test Loss: 2.67085
# Epoch 700, train_idnex=3, Train Loss: 0.86611, Test Loss: 2.44727
# Epoch 800, train_idnex=3, Train Loss: 0.79182, Test Loss: 2.33107
# Epoch 900, train_idnex=3, Train Loss: 0.74675, Test Loss: 2.28998
# Epoch 1000, train_idnex=3, Train Loss: 0.72532, Test Loss: 2.25604
# Epoch 1100, train_idnex=3, Train Loss: 0.71587, Test Loss: 2.24179
# Epoch 1200, train_idnex=3, Train Loss: 0.70934, Test Loss: 2.23857
# Epoch 1300, train_idnex=3, Train Loss: 0.70555, Test Loss: 2.23604
# Epoch 1400, train_idnex=3, Train Loss: 0.70413, Test Loss: 2.23510
# Epoch 1500, train_idnex=3, Train Loss: 0.70362, Test Loss: 2.23359
# loss csv 文件已保存到: /home/admin123/SATData/Run/SeEANet/04-16-19:42:36/MJ_PCA_260_256/output_3.csv
# loss png 文件已保存到: /home/admin123/SATData/Run/SeEANet/04-16-19:42:36/MJ_PCA_260_256/loss_3.png
# 开始第4次训练！！！
# Epoch 100, train_idnex=4, Train Loss: 350.00551, Test Loss: 403.12503
# Epoch 200, train_idnex=4, Train Loss: 18.89702, Test Loss: 25.16902
# Epoch 300, train_idnex=4, Train Loss: 6.32582, Test Loss: 10.70325
# Epoch 400, train_idnex=4, Train Loss: 3.26461, Test Loss: 6.54242
# Epoch 500, train_idnex=4, Train Loss: 2.00793, Test Loss: 4.71778
# Epoch 600, train_idnex=4, Train Loss: 1.46351, Test Loss: 4.09337
# Epoch 700, train_idnex=4, Train Loss: 1.24305, Test Loss: 3.79445
# Epoch 800, train_idnex=4, Train Loss: 1.12989, Test Loss: 3.64720
# Epoch 900, train_idnex=4, Train Loss: 1.07900, Test Loss: 3.55886
# Epoch 1000, train_idnex=4, Train Loss: 1.05248, Test Loss: 3.53141
# Epoch 1100, train_idnex=4, Train Loss: 1.03703, Test Loss: 3.51233
# Epoch 1200, train_idnex=4, Train Loss: 1.03031, Test Loss: 3.50679
# Epoch 1300, train_idnex=4, Train Loss: 1.02619, Test Loss: 3.50197
# Epoch 1400, train_idnex=4, Train Loss: 1.02391, Test Loss: 3.49906
# Epoch 1500, train_idnex=4, Train Loss: 1.02262, Test Loss: 3.49741
# loss csv 文件已保存到: /home/admin123/SATData/Run/SeEANet/04-16-19:42:36/MJ_PCA_260_256/output_4.csv
# loss png 文件已保存到: /home/admin123/SATData/Run/SeEANet/04-16-19:42:36/MJ_PCA_260_256/loss_4.png
# 开始第5次训练！！！
# Epoch 100, train_idnex=5, Train Loss: 28218.37918, Test Loss: 29281.08105
# Epoch 200, train_idnex=5, Train Loss: 71.74941, Test Loss: 85.15947
# Epoch 300, train_idnex=5, Train Loss: 15.05555, Test Loss: 21.76348
# Epoch 400, train_idnex=5, Train Loss: 6.51195, Test Loss: 10.23327
# Epoch 500, train_idnex=5, Train Loss: 3.77477, Test Loss: 6.52771
# Epoch 600, train_idnex=5, Train Loss: 2.68091, Test Loss: 5.15772
# Epoch 700, train_idnex=5, Train Loss: 2.23650, Test Loss: 4.46922
# Epoch 800, train_idnex=5, Train Loss: 2.03086, Test Loss: 4.21742
# Epoch 900, train_idnex=5, Train Loss: 1.89241, Test Loss: 4.06056
# Epoch 1000, train_idnex=5, Train Loss: 1.83515, Test Loss: 3.96532
# Epoch 1100, train_idnex=5, Train Loss: 1.80358, Test Loss: 3.92838
# Epoch 1200, train_idnex=5, Train Loss: 1.78625, Test Loss: 3.91439
# Epoch 1300, train_idnex=5, Train Loss: 1.77886, Test Loss: 3.90723
# Epoch 1400, train_idnex=5, Train Loss: 1.77493, Test Loss: 3.90622
# Epoch 1500, train_idnex=5, Train Loss: 1.77215, Test Loss: 3.90033
# loss csv 文件已保存到: /home/admin123/SATData/Run/SeEANet/04-16-19:42:36/MJ_PCA_260_256/output_5.csv
# loss png 文件已保存到: /home/admin123/SATData/Run/SeEANet/04-16-19:42:36/MJ_PCA_260_256/loss_5.png
# Processing:  50%|█████     | 1/2 [57:19<57:19, 3439.19s/it]
# metrics.json 文件已保存到: /home/admin123/SATData/Run/SeEANet/04-16-19:42:36/MJ_PCA_260_256/metrics.json
# 训练参数：网络：SeEANet, 簇:6, 间隔时间: 300, 数据融合算法: PCA
# semg 数据形状为： torch.Size([23845, 6, 256])
# angle 数据形状为： torch.Size([23845, 3])
# 开始第1次训练！！！
# Epoch 100, train_idnex=1, Train Loss: 348.32890, Test Loss: 380.29838
# Epoch 200, train_idnex=1, Train Loss: 17.88510, Test Loss: 23.35874
# Epoch 300, train_idnex=1, Train Loss: 6.26303, Test Loss: 9.81224
# Epoch 400, train_idnex=1, Train Loss: 2.25007, Test Loss: 4.90750
# Epoch 500, train_idnex=1, Train Loss: 1.39606, Test Loss: 3.63347
# Epoch 600, train_idnex=1, Train Loss: 0.93169, Test Loss: 2.97698
# Epoch 700, train_idnex=1, Train Loss: 0.75979, Test Loss: 2.67008
# Epoch 800, train_idnex=1, Train Loss: 0.68234, Test Loss: 2.52892
# Epoch 900, train_idnex=1, Train Loss: 0.64146, Test Loss: 2.44629
# Epoch 1000, train_idnex=1, Train Loss: 0.61956, Test Loss: 2.41067
# Epoch 1100, train_idnex=1, Train Loss: 0.60976, Test Loss: 2.40247
# Epoch 1200, train_idnex=1, Train Loss: 0.60444, Test Loss: 2.39607
# Epoch 1300, train_idnex=1, Train Loss: 0.60121, Test Loss: 2.39021
# Epoch 1400, train_idnex=1, Train Loss: 0.60025, Test Loss: 2.38861
# Epoch 1500, train_idnex=1, Train Loss: 0.60013, Test Loss: 2.38824
# loss csv 文件已保存到: /home/admin123/SATData/Run/SeEANet/04-16-19:42:36/MJ_PCA_300_256/output_1.csv
# loss png 文件已保存到: /home/admin123/SATData/Run/SeEANet/04-16-19:42:36/MJ_PCA_300_256/loss_1.png
# 开始第2次训练！！！
# Epoch 100, train_idnex=2, Train Loss: 242.29225, Test Loss: 237.51172
# Epoch 200, train_idnex=2, Train Loss: 20.33915, Test Loss: 24.32480
# Epoch 300, train_idnex=2, Train Loss: 4.35319, Test Loss: 6.66473
# Epoch 400, train_idnex=2, Train Loss: 1.88401, Test Loss: 3.73502
# Epoch 500, train_idnex=2, Train Loss: 1.03798, Test Loss: 2.56946
# Epoch 600, train_idnex=2, Train Loss: 0.73023, Test Loss: 2.07186
# Epoch 700, train_idnex=2, Train Loss: 0.58958, Test Loss: 1.87239
# Epoch 800, train_idnex=2, Train Loss: 0.52845, Test Loss: 1.79904
# Epoch 900, train_idnex=2, Train Loss: 0.49417, Test Loss: 1.76340
# Epoch 1000, train_idnex=2, Train Loss: 0.47883, Test Loss: 1.74686
# Epoch 1100, train_idnex=2, Train Loss: 0.47122, Test Loss: 1.73623
# Epoch 1200, train_idnex=2, Train Loss: 0.46667, Test Loss: 1.73161
# Epoch 1300, train_idnex=2, Train Loss: 0.46393, Test Loss: 1.72711
# Epoch 1400, train_idnex=2, Train Loss: 0.46273, Test Loss: 1.72659
# Epoch 1500, train_idnex=2, Train Loss: 0.46247, Test Loss: 1.72768
# loss csv 文件已保存到: /home/admin123/SATData/Run/SeEANet/04-16-19:42:36/MJ_PCA_300_256/output_2.csv
# loss png 文件已保存到: /home/admin123/SATData/Run/SeEANet/04-16-19:42:36/MJ_PCA_300_256/loss_2.png
# 开始第3次训练！！！
# Epoch 100, train_idnex=3, Train Loss: 651.34864, Test Loss: 575.30353
# Epoch 200, train_idnex=3, Train Loss: 14.72249, Test Loss: 22.14610
# Epoch 300, train_idnex=3, Train Loss: 5.93200, Test Loss: 7.33331
# Epoch 400, train_idnex=3, Train Loss: 2.01281, Test Loss: 3.58766
# Epoch 500, train_idnex=3, Train Loss: 1.06130, Test Loss: 2.59956
# Epoch 600, train_idnex=3, Train Loss: 0.73985, Test Loss: 2.12111
# Epoch 700, train_idnex=3, Train Loss: 0.60147, Test Loss: 1.97387
# Epoch 800, train_idnex=3, Train Loss: 0.53665, Test Loss: 1.86390
# Epoch 900, train_idnex=3, Train Loss: 0.50603, Test Loss: 1.83060
# Epoch 1000, train_idnex=3, Train Loss: 0.49046, Test Loss: 1.81391
# Epoch 1100, train_idnex=3, Train Loss: 0.48243, Test Loss: 1.80340
# Epoch 1200, train_idnex=3, Train Loss: 0.47830, Test Loss: 1.80088
# Epoch 1300, train_idnex=3, Train Loss: 0.47501, Test Loss: 1.79768
# Epoch 1400, train_idnex=3, Train Loss: 0.47378, Test Loss: 1.79590
# Epoch 1500, train_idnex=3, Train Loss: 0.47298, Test Loss: 1.79469
# loss csv 文件已保存到: /home/admin123/SATData/Run/SeEANet/04-16-19:42:36/MJ_PCA_300_256/output_3.csv
# loss png 文件已保存到: /home/admin123/SATData/Run/SeEANet/04-16-19:42:36/MJ_PCA_300_256/loss_3.png
# 开始第4次训练！！！
# Epoch 100, train_idnex=4, Train Loss: 28022.48383, Test Loss: 28366.04919
# Epoch 200, train_idnex=4, Train Loss: 175.82257, Test Loss: 217.08346
# Epoch 300, train_idnex=4, Train Loss: 19.26125, Test Loss: 26.29794
# Epoch 400, train_idnex=4, Train Loss: 7.65795, Test Loss: 10.10895
# Epoch 500, train_idnex=4, Train Loss: 4.13330, Test Loss: 6.02169
# Epoch 600, train_idnex=4, Train Loss: 2.91291, Test Loss: 4.47324
# Epoch 700, train_idnex=4, Train Loss: 2.35107, Test Loss: 3.78475
# Epoch 800, train_idnex=4, Train Loss: 2.09469, Test Loss: 3.46980
# Epoch 900, train_idnex=4, Train Loss: 1.96461, Test Loss: 3.30279
# Epoch 1000, train_idnex=4, Train Loss: 1.88843, Test Loss: 3.24429
# Epoch 1100, train_idnex=4, Train Loss: 1.85567, Test Loss: 3.19815
# Epoch 1200, train_idnex=4, Train Loss: 1.83605, Test Loss: 3.18499
# Epoch 1300, train_idnex=4, Train Loss: 1.82491, Test Loss: 3.17533
# Epoch 1400, train_idnex=4, Train Loss: 1.82241, Test Loss: 3.17013
# Epoch 1500, train_idnex=4, Train Loss: 1.81774, Test Loss: 3.17008
# loss csv 文件已保存到: /home/admin123/SATData/Run/SeEANet/04-16-19:42:36/MJ_PCA_300_256/output_4.csv
# loss png 文件已保存到: /home/admin123/SATData/Run/SeEANet/04-16-19:42:36/MJ_PCA_300_256/loss_4.png
# 开始第5次训练！！！
# Epoch 100, train_idnex=5, Train Loss: 867.25017, Test Loss: 805.89061
# Epoch 200, train_idnex=5, Train Loss: 33.96618, Test Loss: 45.74758
# Epoch 300, train_idnex=5, Train Loss: 8.13917, Test Loss: 10.45822
# Epoch 400, train_idnex=5, Train Loss: 2.76905, Test Loss: 5.66490
# Epoch 500, train_idnex=5, Train Loss: 1.57785, Test Loss: 4.04333
# Epoch 600, train_idnex=5, Train Loss: 1.04864, Test Loss: 3.35635
# Epoch 700, train_idnex=5, Train Loss: 0.85027, Test Loss: 3.02831
# Epoch 800, train_idnex=5, Train Loss: 0.76547, Test Loss: 2.91871
# Epoch 900, train_idnex=5, Train Loss: 0.72228, Test Loss: 2.85137
# Epoch 1000, train_idnex=5, Train Loss: 0.70070, Test Loss: 2.81838
# Epoch 1100, train_idnex=5, Train Loss: 0.68685, Test Loss: 2.80135
# Epoch 1200, train_idnex=5, Train Loss: 0.68091, Test Loss: 2.79696
# Epoch 1300, train_idnex=5, Train Loss: 0.67781, Test Loss: 2.79090
# Epoch 1400, train_idnex=5, Train Loss: 0.67611, Test Loss: 2.79010
# Epoch 1500, train_idnex=5, Train Loss: 0.67649, Test Loss: 2.79029
# loss csv 文件已保存到: /home/admin123/SATData/Run/SeEANet/04-16-19:42:36/MJ_PCA_300_256/output_5.csv
# loss png 文件已保存到: /home/admin123/SATData/Run/SeEANet/04-16-19:42:36/MJ_PCA_300_256/loss_5.png
# Processing: 100%|██████████| 2/2 [1:54:19<00:00, 3429.93s/it]
# metrics.json 文件已保存到: /home/admin123/SATData/Run/SeEANet/04-16-19:42:36/MJ_PCA_300_256/metrics.json
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 53
#      50 # 指定 JSON 文件路径
#      51 file_path = os.path.join('/home/admin123/SATData/Run/', formatted_time, "data.json")
# ---> 53 with open(file_path, "w", encoding="utf-8") as file:
#      54     json.dump(data_dict, file, ensure_ascii=False, indent=4)
#      56 print(f"字典已成功保存到 {file_path}")
#
# File ~/anaconda3/envs/pt/lib/python3.9/site-packages/IPython/core/interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/admin123/SATData/Run/04-16-19:42:36/data.json'
