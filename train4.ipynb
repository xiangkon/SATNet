# %%
# 验证 delta_T
from utils.train_func import train_func
from datetime import datetime
from tqdm import tqdm
import numpy as np
import json
import os
import matplotlib.pyplot as plt
from utils.tools import make_dir, plot_func


modelList = ['SeEANet', 'SAT', 'MyoNet']
data_dict = {}
# delta_Tlist = [1, 10, 15, 20, 25, 30, 40, 50, 60]
# delta_Tlist = [1, 5, 10, 15, 20, 25, 30, 35, 40, 50, 60, 70, 80, 90 ,100, 120, 140, 160, 180, 200, 230, 260, 300]
# delta_Tlist = [260, 300]

# # people_List = ['S01', 'S02', "S03"]
# people_List = ['S01']

# delta_Tlist = [i for i in range(21, 31)]
people_List = ['S01', 'S02', "S03", "S04", "S05"]
# people_List = ['S01']

delta_T  = 17
# WLlist = [32, 64, 96, 128]
WindowLength = 256

fushion_MethodList = ["EVA", "WA"]
saveDir = "/home/admin123/SATData/Run"
dataDir = "/home/admin123/SATData/data"
# CNList = [4, 12]
cluster_name = 6
rmseL = []
maeL = []
r2L = []
formatted_time = datetime.now().strftime("%m-%d-%H:%M:%S")
make_dir(os.path.join(saveDir, formatted_time))
for fushionMethod in tqdm(fushion_MethodList, desc="Processing", position=0):
    rmse, mae, r2 = train_func(modelName='SeEANet', epochs=5, train_num=2, delta_T=delta_T, windowLength=WindowLength, cluster_num=cluster_name,
                               formatted_time = formatted_time, peopleList=people_List, batch_size=256,
                               data_Dir=dataDir, save_Dir=saveDir, fusionMethod=fushionMethod)
    rmse = np.array(rmse)
    rmse_m = np.mean(rmse,axis=0)
    rmse_s = np.std(rmse, axis=0)
    rmse_d = np.max(rmse, axis=0)-np.min(rmse, axis=0)
    rmseL.append(rmse_m)

    mae = np.array(mae)
    mae_m = np.mean(mae,axis=0)
    mae_s = np.std(mae, axis=0)
    mae_d = np.max(mae, axis=0)-np.min(mae, axis=0)
    maeL.append(mae_m)

    r2 = np.array(r2)
    r2_m = np.mean(r2,axis=0)
    r2_s = np.std(r2, axis=0)
    r2_d = np.max(r2, axis=0)-np.min(r2, axis=0)
    r2L.append(r2_m)

    data_dict[f"rmse_{delta_T}"] = [list(rmse_m), list(rmse_s), list(rmse_d)]
    data_dict[f"mae_{delta_T}"] = [list(mae_m), list(mae_s), list(mae_d)]
    data_dict[f"r2_{delta_T}"] = [list(r2_m), list(r2_s), list(r2_d)]

# 指定 JSON 文件路径
file_path = os.path.join(saveDir, formatted_time, "data.json")

with open(file_path, "w", encoding="utf-8") as file:
    json.dump(data_dict, file, ensure_ascii=False, indent=4)

print(f"字典已成功保存到 {file_path}")


rmseL = np.array(rmseL)
maeL = np.array(maeL)
r2L = np.array(r2L)

List = [i for i in range(len(fushion_MethodList))]
Xlabel = "Cluster Num"

saveFolderName = "CN——指标对比"
save_Dir = os.path.join('/home/admin123/SATData/Run', "figures", saveFolderName)
plot_func(save_Dir, rmseL, List, Xlabel, "value", 0, None, "RMSE.png")
plot_func(save_Dir, maeL, List, Xlabel, "value", 0, None, "MAE.png")
plot_func(save_Dir, r2L, List, Xlabel, "value", 0, None, "R2.png")
# Out:
# Processing:   0%|          | 0/2 [00:00<?, ?it/s]
# 训练参数：网络：SeEANet, 簇:6, 间隔时间: 17, 数据融合算法: EVA, 窗口大小：256
# semg 数据形状为： torch.Size([133372, 6, 256])
# angle 数据形状为： torch.Size([133372, 3])
# 开始第1次训练！！！
# loss csv 文件已保存到: /home/admin123/SATData/Run/SeEANet/04-28-09:09:09/MJ_EVA_17_256_6/output_1.csv
# loss png 文件已保存到: /home/admin123/SATData/Run/SeEANet/04-28-09:09:09/MJ_EVA_17_256_6/loss_1.png
# metrics.json 文件已保存到: /home/admin123/SATData/Run/SeEANet/04-28-09:09:09/MJ_EVA_17_256_6/metrics_1.json
# 开始第2次训练！！！
# loss csv 文件已保存到: /home/admin123/SATData/Run/SeEANet/04-28-09:09:09/MJ_EVA_17_256_6/output_2.csv
# loss png 文件已保存到: /home/admin123/SATData/Run/SeEANet/04-28-09:09:09/MJ_EVA_17_256_6/loss_2.png
# Processing:  50%|█████     | 1/2 [00:21<00:21, 21.96s/it]
# metrics.json 文件已保存到: /home/admin123/SATData/Run/SeEANet/04-28-09:09:09/MJ_EVA_17_256_6/metrics_2.json
# 训练参数：网络：SeEANet, 簇:6, 间隔时间: 17, 数据融合算法: WA, 窗口大小：256
# semg 数据形状为： torch.Size([133372, 6, 256])
# angle 数据形状为： torch.Size([133372, 3])
# 开始第1次训练！！！
# loss csv 文件已保存到: /home/admin123/SATData/Run/SeEANet/04-28-09:09:09/MJ_WA_17_256_6/output_1.csv
# loss png 文件已保存到: /home/admin123/SATData/Run/SeEANet/04-28-09:09:09/MJ_WA_17_256_6/loss_1.png
# metrics.json 文件已保存到: /home/admin123/SATData/Run/SeEANet/04-28-09:09:09/MJ_WA_17_256_6/metrics_1.json
# 开始第2次训练！！！
# loss csv 文件已保存到: /home/admin123/SATData/Run/SeEANet/04-28-09:09:09/MJ_WA_17_256_6/output_2.csv
# loss png 文件已保存到: /home/admin123/SATData/Run/SeEANet/04-28-09:09:09/MJ_WA_17_256_6/loss_2.png
# Processing: 100%|██████████| 2/2 [00:43<00:00, 21.61s/it]
# metrics.json 文件已保存到: /home/admin123/SATData/Run/SeEANet/04-28-09:09:09/MJ_WA_17_256_6/metrics_2.json
# 字典已成功保存到 /home/admin123/SATData/Run/04-28-09:09:09/data.json

# %%
# 验证 delta_T
from utils.train_func import train_func
from datetime import datetime
from tqdm import tqdm
import numpy as np
import json
import os
import matplotlib.pyplot as plt
from utils.tools import make_dir


modelList = ['SeEANet', 'SAT', 'MyoNet']
data_dict = {}
# delta_Tlist = [1, 10, 15, 20, 25, 30, 40, 50, 60]
# delta_Tlist = [1, 5, 10, 15, 20, 25, 30, 35, 40, 50, 60, 70, 80, 90 ,100, 120, 140, 160, 180, 200, 230, 260, 300]
# delta_Tlist = [260, 300]

# # people_List = ['S01', 'S02', "S03"]
# people_List = ['S01']

# delta_Tlist = [i for i in range(21, 31)]
people_List = ['S01', 'S02', "S03", "S04", "S05"]
# people_List = ['S01']

delta_T  = 17
WLlist = [160, 192, 224, 256]

saveDir = "/home/admin123/SATData/Run"
dataDir = "/home/admin123/SATData/data"

rmseL = []
maeL = []
r2L = []
formatted_time = datetime.now().strftime("%m-%d-%H:%M:%S")
make_dir(os.path.join(saveDir, formatted_time))
for WindowLength in tqdm(WLlist, desc="Processing", position=0):
    rmse, mae, r2 = train_func(modelName='SeEANet', epochs=1500, train_num=10, delta_T=delta_T, windowLength=WindowLength, 
                               formatted_time = formatted_time, peopleList=people_List, batch_size=256,
                               data_Dir=dataDir, save_Dir=saveDir)
    rmse = np.array(rmse)
    rmse_m = np.mean(rmse,axis=0)
    rmse_s = np.std(rmse, axis=0)
    rmse_d = np.max(rmse, axis=0)-np.min(rmse, axis=0)
    rmseL.append(rmse_m)

    mae = np.array(mae)
    mae_m = np.mean(mae,axis=0)
    mae_s = np.std(mae, axis=0)
    mae_d = np.max(mae, axis=0)-np.min(mae, axis=0)
    maeL.append(mae_m)

    r2 = np.array(r2)
    r2_m = np.mean(r2,axis=0)
    r2_s = np.std(r2, axis=0)
    r2_d = np.max(r2, axis=0)-np.min(r2, axis=0)
    r2L.append(r2_m)

    data_dict[f"rmse_{delta_T}"] = [list(rmse_m), list(rmse_s), list(rmse_d)]
    data_dict[f"mae_{delta_T}"] = [list(mae_m), list(mae_s), list(mae_d)]
    data_dict[f"r2_{delta_T}"] = [list(r2_m), list(r2_s), list(r2_d)]

# 指定 JSON 文件路径
file_path = os.path.join(saveDir, formatted_time, "data.json")

with open(file_path, "w", encoding="utf-8") as file:
    json.dump(data_dict, file, ensure_ascii=False, indent=4)

print(f"字典已成功保存到 {file_path}")


rmseL = np.array(rmseL)
maeL = np.array(maeL)
r2L = np.array(r2L)
delta_Tlist = WLlist
plt.figure()
png_path = os.path.join(saveDir, formatted_time, "RMSE.png")
plt.plot(delta_Tlist, rmseL[:,0], marker='o', linestyle='-', label='elv_angle')  # 线条和点
plt.plot(delta_Tlist, rmseL[:,1], marker='o', linestyle='-', label='shoulder_elv')  # 线条和点
plt.plot(delta_Tlist, rmseL[:,2], marker='o', linestyle='-', label='elbow_flexion')  # 线条和点
plt.xlabel("WL")
plt.ylabel("value")
plt.grid()
plt.legend()
plt.title("RMSE")
plt.savefig(png_path, dpi=300, bbox_inches='tight')
# plt.scatter(x, y, color='r', label='Points')  # 单独绘制点 


plt.figure()
png_path = os.path.join(saveDir, formatted_time, "MAE.png")
plt.plot(delta_Tlist, rmseL[:,0], marker='o', linestyle='-', label='elv_angle')  # 线条和点
plt.plot(delta_Tlist, rmseL[:,1], marker='o', linestyle='-', label='shoulder_elv')  # 线条和点
plt.plot(delta_Tlist, rmseL[:,2], marker='o', linestyle='-', label='elbow_flexion')  # 线条和点
plt.xlabel("WL")
plt.ylabel("value")
plt.title("MAE")
plt.grid()
plt.legend()
plt.savefig(png_path, dpi=300, bbox_inches='tight')


plt.figure()
png_path = os.path.join(saveDir, formatted_time, "R2.png")
plt.plot(delta_Tlist, rmseL[:,0], marker='o', linestyle='-', label='elv_angle')  # 线条和点
plt.plot(delta_Tlist, rmseL[:,1], marker='o', linestyle='-', label='shoulder_elv')  # 线条和点
plt.plot(delta_Tlist, rmseL[:,2], marker='o', linestyle='-', label='elbow_flexion')  # 线条和点
plt.xlabel("WL")
plt.ylabel("value")
plt.title("R2")
plt.grid()
plt.legend()
plt.savefig(png_path, dpi=300, bbox_inches='tight')
# Out:
# Processing:   0%|          | 0/1 [00:00<?, ?it/s]
# 训练参数：网络：SeEANet, 簇:6, 间隔时间: 18, 数据融合算法: PCA
# semg 数据形状为： torch.Size([133322, 6, 256])
# angle 数据形状为： torch.Size([133322, 3])
# 开始第1次训练！！！
# Epoch 100, train_idnex=1, Train Loss: 356.11522, Test Loss: 329.01707
# Epoch 200, train_idnex=1, Train Loss: 162.11401, Test Loss: 118.78998
# Epoch 300, train_idnex=1, Train Loss: 37.22907, Test Loss: 51.89741
# Epoch 400, train_idnex=1, Train Loss: 21.68470, Test Loss: 31.05304
# Epoch 500, train_idnex=1, Train Loss: 13.73528, Test Loss: 21.88568
# Epoch 600, train_idnex=1, Train Loss: 11.07845, Test Loss: 19.13139
# Epoch 700, train_idnex=1, Train Loss: 9.81037, Test Loss: 17.35823
# Epoch 800, train_idnex=1, Train Loss: 9.20435, Test Loss: 16.61511
# Epoch 900, train_idnex=1, Train Loss: 8.89721, Test Loss: 16.33453
# Epoch 1000, train_idnex=1, Train Loss: 8.73787, Test Loss: 16.13506
# Epoch 1100, train_idnex=1, Train Loss: 8.65885, Test Loss: 16.08336
# Epoch 1200, train_idnex=1, Train Loss: 8.61541, Test Loss: 16.04257
# Epoch 1300, train_idnex=1, Train Loss: 8.59224, Test Loss: 16.01980
# Epoch 1400, train_idnex=1, Train Loss: 8.58016, Test Loss: 16.00848
# Epoch 1500, train_idnex=1, Train Loss: 8.57015, Test Loss: 16.01073
# loss csv 文件已保存到: /home/admin123/SATData/Run/SeEANet/04-22-11:34:05/MJ_PCA_18_256/output_1.csv
# loss png 文件已保存到: /home/admin123/SATData/Run/SeEANet/04-22-11:34:05/MJ_PCA_18_256/loss_1.png
# 开始第2次训练！！！
# Epoch 100, train_idnex=2, Train Loss: 241.97733, Test Loss: 219.98837
# Epoch 200, train_idnex=2, Train Loss: 80.46417, Test Loss: 84.12501
# Epoch 300, train_idnex=2, Train Loss: 35.70086, Test Loss: 45.94450
# Epoch 400, train_idnex=2, Train Loss: 14.19138, Test Loss: 21.53342
# Epoch 500, train_idnex=2, Train Loss: 9.74345, Test Loss: 15.99436
# Epoch 600, train_idnex=2, Train Loss: 7.76527, Test Loss: 13.36476
# Epoch 700, train_idnex=2, Train Loss: 6.86571, Test Loss: 12.36191
# Epoch 800, train_idnex=2, Train Loss: 6.43603, Test Loss: 11.77404
# Epoch 900, train_idnex=2, Train Loss: 6.22434, Test Loss: 11.59095
# Epoch 1000, train_idnex=2, Train Loss: 6.11598, Test Loss: 11.51808
# Epoch 1100, train_idnex=2, Train Loss: 6.05647, Test Loss: 11.44440
# Epoch 1200, train_idnex=2, Train Loss: 6.02762, Test Loss: 11.42413
# Epoch 1300, train_idnex=2, Train Loss: 6.00951, Test Loss: 11.40529
# Epoch 1400, train_idnex=2, Train Loss: 6.00063, Test Loss: 11.39667
# Epoch 1500, train_idnex=2, Train Loss: 5.99437, Test Loss: 11.39540
# loss csv 文件已保存到: /home/admin123/SATData/Run/SeEANet/04-22-11:34:05/MJ_PCA_18_256/output_2.csv
# loss png 文件已保存到: /home/admin123/SATData/Run/SeEANet/04-22-11:34:05/MJ_PCA_18_256/loss_2.png
# 开始第3次训练！！！
# Epoch 100, train_idnex=3, Train Loss: 809.77042, Test Loss: 557.95818
# Epoch 200, train_idnex=3, Train Loss: 101.44447, Test Loss: 119.41327
# Epoch 300, train_idnex=3, Train Loss: 48.37545, Test Loss: 54.35049
# Epoch 400, train_idnex=3, Train Loss: 22.59082, Test Loss: 32.81814
# Epoch 500, train_idnex=3, Train Loss: 14.95915, Test Loss: 23.98614
# Epoch 600, train_idnex=3, Train Loss: 12.18053, Test Loss: 20.90497
# Epoch 700, train_idnex=3, Train Loss: 10.82726, Test Loss: 19.24600
# Epoch 800, train_idnex=3, Train Loss: 10.18545, Test Loss: 18.69288
# Epoch 900, train_idnex=3, Train Loss: 9.87499, Test Loss: 18.32328
# Epoch 1000, train_idnex=3, Train Loss: 9.70442, Test Loss: 18.16366
# Epoch 1100, train_idnex=3, Train Loss: 9.61870, Test Loss: 18.09070
# Epoch 1200, train_idnex=3, Train Loss: 9.57615, Test Loss: 18.03546
# Epoch 1300, train_idnex=3, Train Loss: 9.55167, Test Loss: 18.01521
# Epoch 1400, train_idnex=3, Train Loss: 9.53876, Test Loss: 18.00880
# Epoch 1500, train_idnex=3, Train Loss: 9.53048, Test Loss: 18.00620
# loss csv 文件已保存到: /home/admin123/SATData/Run/SeEANet/04-22-11:34:05/MJ_PCA_18_256/output_3.csv
# loss png 文件已保存到: /home/admin123/SATData/Run/SeEANet/04-22-11:34:05/MJ_PCA_18_256/loss_3.png
# 开始第4次训练！！！
# Epoch 100, train_idnex=4, Train Loss: 495.23992, Test Loss: 1128.92923
# Epoch 200, train_idnex=4, Train Loss: 68.69685, Test Loss: 96.45888
# Epoch 300, train_idnex=4, Train Loss: 28.22064, Test Loss: 35.89661
# Epoch 400, train_idnex=4, Train Loss: 13.36968, Test Loss: 20.36052
# Epoch 500, train_idnex=4, Train Loss: 8.71683, Test Loss: 14.21910
# Epoch 600, train_idnex=4, Train Loss: 6.76909, Test Loss: 12.04232
# Epoch 700, train_idnex=4, Train Loss: 5.94015, Test Loss: 11.12992
# Epoch 800, train_idnex=4, Train Loss: 5.56193, Test Loss: 10.71716
# Epoch 900, train_idnex=4, Train Loss: 5.37637, Test Loss: 10.51872
# Epoch 1000, train_idnex=4, Train Loss: 5.27612, Test Loss: 10.43971
# Epoch 1100, train_idnex=4, Train Loss: 5.22355, Test Loss: 10.39155
# Epoch 1200, train_idnex=4, Train Loss: 5.19840, Test Loss: 10.37130
# Epoch 1300, train_idnex=4, Train Loss: 5.18394, Test Loss: 10.35642
# Epoch 1400, train_idnex=4, Train Loss: 5.17538, Test Loss: 10.35207
# Epoch 1500, train_idnex=4, Train Loss: 5.16854, Test Loss: 10.34921
# loss csv 文件已保存到: /home/admin123/SATData/Run/SeEANet/04-22-11:34:05/MJ_PCA_18_256/output_4.csv
# loss png 文件已保存到: /home/admin123/SATData/Run/SeEANet/04-22-11:34:05/MJ_PCA_18_256/loss_4.png
# 开始第5次训练！！！
# Epoch 100, train_idnex=5, Train Loss: 179.73705, Test Loss: 244.37878
# Epoch 200, train_idnex=5, Train Loss: 60.87439, Test Loss: 62.81806
# Epoch 300, train_idnex=5, Train Loss: 33.81564, Test Loss: 35.17098
# Epoch 400, train_idnex=5, Train Loss: 12.12425, Test Loss: 20.30734
# Epoch 500, train_idnex=5, Train Loss: 7.92395, Test Loss: 14.42314
# Epoch 600, train_idnex=5, Train Loss: 6.29371, Test Loss: 12.44050
# Epoch 700, train_idnex=5, Train Loss: 5.56127, Test Loss: 11.39557
# Epoch 800, train_idnex=5, Train Loss: 5.20547, Test Loss: 10.94566
# Epoch 900, train_idnex=5, Train Loss: 5.02655, Test Loss: 10.75394
# Epoch 1000, train_idnex=5, Train Loss: 4.93407, Test Loss: 10.67478
# Epoch 1100, train_idnex=5, Train Loss: 4.88567, Test Loss: 10.62102
# Epoch 1200, train_idnex=5, Train Loss: 4.86081, Test Loss: 10.58971
# Epoch 1300, train_idnex=5, Train Loss: 4.84782, Test Loss: 10.58606
# Epoch 1400, train_idnex=5, Train Loss: 4.84052, Test Loss: 10.58207
# Epoch 1500, train_idnex=5, Train Loss: 4.83456, Test Loss: 10.57887
# loss csv 文件已保存到: /home/admin123/SATData/Run/SeEANet/04-22-11:34:05/MJ_PCA_18_256/output_5.csv
# loss png 文件已保存到: /home/admin123/SATData/Run/SeEANet/04-22-11:34:05/MJ_PCA_18_256/loss_5.png
# 开始第6次训练！！！
# Epoch 100, train_idnex=6, Train Loss: 415.98030, Test Loss: 489.88060
# Epoch 200, train_idnex=6, Train Loss: 118.37858, Test Loss: 155.07250
# Epoch 300, train_idnex=6, Train Loss: 54.68639, Test Loss: 86.75677
# Epoch 400, train_idnex=6, Train Loss: 24.41652, Test Loss: 33.13640
# Epoch 500, train_idnex=6, Train Loss: 16.22004, Test Loss: 26.58386
# Epoch 600, train_idnex=6, Train Loss: 12.94780, Test Loss: 21.45168
# Epoch 700, train_idnex=6, Train Loss: 11.53772, Test Loss: 20.11008
# Epoch 800, train_idnex=6, Train Loss: 10.80406, Test Loss: 19.23025
# Epoch 900, train_idnex=6, Train Loss: 10.47959, Test Loss: 18.88400
# Epoch 1000, train_idnex=6, Train Loss: 10.29221, Test Loss: 18.67741
# Epoch 1100, train_idnex=6, Train Loss: 10.19376, Test Loss: 18.59447
# Epoch 1200, train_idnex=6, Train Loss: 10.14603, Test Loss: 18.54568
# Epoch 1300, train_idnex=6, Train Loss: 10.11751, Test Loss: 18.53319
# Epoch 1400, train_idnex=6, Train Loss: 10.10366, Test Loss: 18.52036
# Epoch 1500, train_idnex=6, Train Loss: 10.09249, Test Loss: 18.51940
# loss csv 文件已保存到: /home/admin123/SATData/Run/SeEANet/04-22-11:34:05/MJ_PCA_18_256/output_6.csv
# loss png 文件已保存到: /home/admin123/SATData/Run/SeEANet/04-22-11:34:05/MJ_PCA_18_256/loss_6.png
# 开始第7次训练！！！
# Epoch 100, train_idnex=7, Train Loss: 514.96546, Test Loss: 311.85749
# Epoch 200, train_idnex=7, Train Loss: 60.90274, Test Loss: 76.88012
# Epoch 300, train_idnex=7, Train Loss: 27.41186, Test Loss: 36.59243
# Epoch 400, train_idnex=7, Train Loss: 13.00945, Test Loss: 20.42742
# Epoch 500, train_idnex=7, Train Loss: 8.47625, Test Loss: 14.23574
# Epoch 600, train_idnex=7, Train Loss: 6.74642, Test Loss: 12.23308
# Epoch 700, train_idnex=7, Train Loss: 5.90694, Test Loss: 11.41581
# Epoch 800, train_idnex=7, Train Loss: 5.52673, Test Loss: 10.93730
# Epoch 900, train_idnex=7, Train Loss: 5.33377, Test Loss: 10.76134
# Epoch 1000, train_idnex=7, Train Loss: 5.23124, Test Loss: 10.66617
# Epoch 1100, train_idnex=7, Train Loss: 5.18000, Test Loss: 10.61019
# Epoch 1200, train_idnex=7, Train Loss: 5.15370, Test Loss: 10.58347
# Epoch 1300, train_idnex=7, Train Loss: 5.13840, Test Loss: 10.57450
# Epoch 1400, train_idnex=7, Train Loss: 5.13047, Test Loss: 10.56445
# Epoch 1500, train_idnex=7, Train Loss: 5.12440, Test Loss: 10.56391
# loss csv 文件已保存到: /home/admin123/SATData/Run/SeEANet/04-22-11:34:05/MJ_PCA_18_256/output_7.csv
# loss png 文件已保存到: /home/admin123/SATData/Run/SeEANet/04-22-11:34:05/MJ_PCA_18_256/loss_7.png
# 开始第8次训练！！！
# Epoch 100, train_idnex=8, Train Loss: 581.80378, Test Loss: 286.36779
# Epoch 200, train_idnex=8, Train Loss: 86.46711, Test Loss: 89.29312
# Epoch 300, train_idnex=8, Train Loss: 32.47643, Test Loss: 37.26636
# Epoch 400, train_idnex=8, Train Loss: 14.05628, Test Loss: 22.67599
# Epoch 500, train_idnex=8, Train Loss: 9.17785, Test Loss: 14.86244
# Epoch 600, train_idnex=8, Train Loss: 7.24377, Test Loss: 12.69626
# Epoch 700, train_idnex=8, Train Loss: 6.39067, Test Loss: 11.66929
# Epoch 800, train_idnex=8, Train Loss: 5.98530, Test Loss: 11.22888
# Epoch 900, train_idnex=8, Train Loss: 5.77667, Test Loss: 11.04096
# Epoch 1000, train_idnex=8, Train Loss: 5.67076, Test Loss: 10.93994
# Epoch 1100, train_idnex=8, Train Loss: 5.61788, Test Loss: 10.89925
# Epoch 1200, train_idnex=8, Train Loss: 5.58871, Test Loss: 10.85843
# Epoch 1300, train_idnex=8, Train Loss: 5.57137, Test Loss: 10.84986
# Epoch 1400, train_idnex=8, Train Loss: 5.56273, Test Loss: 10.83730
# Epoch 1500, train_idnex=8, Train Loss: 5.55652, Test Loss: 10.83437
# loss csv 文件已保存到: /home/admin123/SATData/Run/SeEANet/04-22-11:34:05/MJ_PCA_18_256/output_8.csv
# loss png 文件已保存到: /home/admin123/SATData/Run/SeEANet/04-22-11:34:05/MJ_PCA_18_256/loss_8.png
# 开始第9次训练！！！
# Epoch 100, train_idnex=9, Train Loss: 317.33041, Test Loss: 422.55089
# Epoch 200, train_idnex=9, Train Loss: 76.22136, Test Loss: 76.30364
# Epoch 300, train_idnex=9, Train Loss: 32.07527, Test Loss: 28.78963
# Epoch 400, train_idnex=9, Train Loss: 12.92892, Test Loss: 18.63962
# Epoch 500, train_idnex=9, Train Loss: 8.05084, Test Loss: 13.02859
# Epoch 600, train_idnex=9, Train Loss: 6.32701, Test Loss: 10.94944
# Epoch 700, train_idnex=9, Train Loss: 5.50718, Test Loss: 10.15068
# Epoch 800, train_idnex=9, Train Loss: 5.13560, Test Loss: 9.72717
# Epoch 900, train_idnex=9, Train Loss: 4.95291, Test Loss: 9.54633
# Epoch 1000, train_idnex=9, Train Loss: 4.85795, Test Loss: 9.46483
# Epoch 1100, train_idnex=9, Train Loss: 4.80740, Test Loss: 9.40126
# Epoch 1200, train_idnex=9, Train Loss: 4.78044, Test Loss: 9.37564
# Epoch 1300, train_idnex=9, Train Loss: 4.76686, Test Loss: 9.36229
# Epoch 1400, train_idnex=9, Train Loss: 4.75926, Test Loss: 9.36109
# Epoch 1500, train_idnex=9, Train Loss: 4.75367, Test Loss: 9.35307
# loss csv 文件已保存到: /home/admin123/SATData/Run/SeEANet/04-22-11:34:05/MJ_PCA_18_256/output_9.csv
# loss png 文件已保存到: /home/admin123/SATData/Run/SeEANet/04-22-11:34:05/MJ_PCA_18_256/loss_9.png
# 开始第10次训练！！！
# Epoch 100, train_idnex=10, Train Loss: 431.10490, Test Loss: 436.88919
# Epoch 200, train_idnex=10, Train Loss: 89.47859, Test Loss: 97.79099
# Epoch 300, train_idnex=10, Train Loss: 29.24833, Test Loss: 44.08359
# Epoch 400, train_idnex=10, Train Loss: 15.01186, Test Loss: 21.59720
# Epoch 500, train_idnex=10, Train Loss: 9.81867, Test Loss: 16.47813
# Epoch 600, train_idnex=10, Train Loss: 7.83178, Test Loss: 13.84979
# Epoch 700, train_idnex=10, Train Loss: 6.97020, Test Loss: 12.68710
# Epoch 800, train_idnex=10, Train Loss: 6.53620, Test Loss: 12.27327
# Epoch 900, train_idnex=10, Train Loss: 6.32236, Test Loss: 12.00800
# Epoch 1000, train_idnex=10, Train Loss: 6.21017, Test Loss: 11.90049
# Epoch 1100, train_idnex=10, Train Loss: 6.15039, Test Loss: 11.83354
# Epoch 1200, train_idnex=10, Train Loss: 6.12140, Test Loss: 11.80429
# Epoch 1300, train_idnex=10, Train Loss: 6.10281, Test Loss: 11.78872
# Epoch 1400, train_idnex=10, Train Loss: 6.09315, Test Loss: 11.78226
# Epoch 1500, train_idnex=10, Train Loss: 6.08641, Test Loss: 11.77784
# loss csv 文件已保存到: /home/admin123/SATData/Run/SeEANet/04-22-11:34:05/MJ_PCA_18_256/output_10.csv
# loss png 文件已保存到: /home/admin123/SATData/Run/SeEANet/04-22-11:34:05/MJ_PCA_18_256/loss_10.png
# Processing: 100%|██████████| 1/1 [10:24:11<00:00, 37451.69s/it]
# metrics.json 文件已保存到: /home/admin123/SATData/Run/SeEANet/04-22-11:34:05/MJ_PCA_18_256/metrics.json
# 字典已成功保存到 /home/admin123/SATData/Run/04-22-11:34:05/data.json
